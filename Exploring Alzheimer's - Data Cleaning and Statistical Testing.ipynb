# %% [markdown]
# # Let's work with another health dataset. Here we are practicing analyzing messy, and unclean data.
#
# ###### Feel free to download an updated copy of the data from the CDC here: https://catalog.data.gov/dataset/alzheimers-disease-and-healthy-aging-data
# -This Jupyter Notebook was written by Robert Feldstein on December 28th, 2022.

# %%
import pandas as pd
import sklearn as sk
import numpy as np 
import matplotlib.pyplot as plt
import scipy.stats as st

# %% [markdown]
# ## Let's take a look at the data to get a better sense of what we are working with.
# #### Government datasets like these are notoriously disorganized and hard to interpret.

# %%
df = pd.read_csv('Alzheimer_s_Disease_and_Healthy_Aging_Data.csv',low_memory=False)
df.head()
# Out:
#    RowId  YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0    NaN       2020     2020           HI       Hawaii      BRFSS
# 1    NaN       2017     2017           ID        Idaho      BRFSS
# 2    NaN       2017     2017           ID        Idaho      BRFSS
# 3    NaN       2018     2018           ID        Idaho      BRFSS
# 4    NaN       2020     2020           IN      Indiana      BRFSS
#
#             Class                                            Topic  \
# 0  Overall Health                     Arthritis among older adults
# 1   Mental Health                 Lifetime diagnosis of depression
# 2  Overall Health                     Arthritis among older adults
# 3  Overall Health  Physically unhealthy days (mean number of days)
# 4   Mental Health                 Lifetime diagnosis of depression
#
#                                             Question  Response  ...  \
# 0  Percentage of older adults ever told they have...       NaN  ...
# 1  Percentage of older adults with a lifetime dia...       NaN  ...
# 2  Percentage of older adults ever told they have...       NaN  ...
# 3  Physically unhealthy days (mean number of days...       NaN  ...
# 4  Percentage of older adults with a lifetime dia...       NaN  ...
#
#   QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 0        Q43        NaN         15                        AGE
# 1        Q27        NaN         16                        AGE
# 2        Q43        NaN         16                        AGE
# 3        Q08        NaN         16                        AGE
# 4        Q27        NaN         18                        AGE
#
#    StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0               5064                   OVERALL           OVERALL
# 1               5064                   OVERALL           OVERALL
# 2               5064                   OVERALL           OVERALL
# 3               5064                   OVERALL           OVERALL
# 4        AGE_OVERALL                    GENDER              MALE
#
#   StratificationCategoryID3 StratificationID3  Report
# 0                       NaN               NaN     NaN
# 1                       NaN               NaN     NaN
# 2                       NaN               NaN     NaN
# 3                       NaN               NaN     NaN
# 4                       NaN               NaN     NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Look's like we have a lot of NaN values here.
# Let's check if some of these columns are completely empty.  If they have no data, we can drop them from the table and save some memory!

# %%
#Here is a quick way to check if entire columns are null
"""
Returns true if the entire series is filled with null values, false otherwise.
    Parameter series: A pandas column
    Precondition: series represents an entire pandas column 
"""
def colisnull(series):
    return series.isnull().all()

#Let's make an array of all the completely empty columns in our dataset
#Here is some nice list comprehension to get a list of all the column names!
empty_columns = [i for i in df.columns if colisnull(df[i])]

#Now we simply drop these columns, and we will have an easier to read dataset 
df = df.drop(empty_columns,axis=1)
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc Datasource           Class  \
# 0       2020     2020           HI       Hawaii      BRFSS  Overall Health
# 1       2017     2017           ID        Idaho      BRFSS   Mental Health
# 2       2017     2017           ID        Idaho      BRFSS  Overall Health
# 3       2018     2018           ID        Idaho      BRFSS  Overall Health
# 4       2020     2020           IN      Indiana      BRFSS   Mental Health
#
#                                              Topic  \
# 0                     Arthritis among older adults
# 1                 Lifetime diagnosis of depression
# 2                     Arthritis among older adults
# 3  Physically unhealthy days (mean number of days)
# 4                 Lifetime diagnosis of depression
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults ever told they have...               %
# 1  Percentage of older adults with a lifetime dia...               %
# 2  Percentage of older adults ever told they have...               %
# 3  Physically unhealthy days (mean number of days...          Number
# 4  Percentage of older adults with a lifetime dia...               %
#
#   DataValueTypeID  ... Stratification2                       Geolocation  \
# 0           PRCTG  ...             NaN  POINT (-157.8577494 21.30485044)
# 1           PRCTG  ...             NaN    POINT (-114.36373 43.68263001)
# 2           PRCTG  ...             NaN    POINT (-114.36373 43.68263001)
# 3            MEAN  ...             NaN    POINT (-114.36373 43.68263001)
# 4           PRCTG  ...            Male  POINT (-86.14996019 39.76691045)
#
#    ClassID TopicID QuestionID LocationID StratificationCategoryID1  \
# 0      C01   TOC11        Q43         15                       AGE
# 1      C05   TMC03        Q27         16                       AGE
# 2      C01   TOC11        Q43         16                       AGE
# 3      C01   TOC01        Q08         16                       AGE
# 4      C05   TMC03        Q27         18                       AGE
#
#   StratificationID1 StratificationCategoryID2 StratificationID2
# 0              5064                   OVERALL           OVERALL
# 1              5064                   OVERALL           OVERALL
# 2              5064                   OVERALL           OVERALL
# 3              5064                   OVERALL           OVERALL
# 4       AGE_OVERALL                    GENDER              MALE
#
# [5 rows x 30 columns]

# %% [markdown]
# ### And just like that we removed 9 columns which contained no information!
# For the sake of improved analysis, I will also be removing columns which contain repetitive information, or information that we cannot decode (like the Government TopicID or Geolocation). This data is certainly useful, but it's more set for ArcGIS. If you are interested in analyzing geographic data, feel free to look at another of my projects: "Projecting Future Urban Flooding".
#
# https://arcg.is/e49fP

# %%
#Further removing of columns
df = df.drop(["LocationAbbr","Datasource","Geolocation","ClassID","TopicID","LocationID","Data_Value_Footnote_Symbol","Data_Value_Footnote"],axis=1)

# %%
#Furthermore, it looks like the Data_Value and Data_Value_Alt columns are exactly the same, let's check!
val = (df["Data_Value"].dropna() == df["Data_Value_Alt"].dropna()).all()
if val:
    df = df.drop(["Data_Value_Alt"],axis=1)
df.head()
# Out:
#    YearStart  YearEnd LocationDesc           Class  \
# 0       2020     2020       Hawaii  Overall Health
# 1       2017     2017        Idaho   Mental Health
# 2       2017     2017        Idaho  Overall Health
# 3       2018     2018        Idaho  Overall Health
# 4       2020     2020      Indiana   Mental Health
#
#                                              Topic  \
# 0                     Arthritis among older adults
# 1                 Lifetime diagnosis of depression
# 2                     Arthritis among older adults
# 3  Physically unhealthy days (mean number of days)
# 4                 Lifetime diagnosis of depression
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults ever told they have...               %
# 1  Percentage of older adults with a lifetime dia...               %
# 2  Percentage of older adults ever told they have...               %
# 3  Physically unhealthy days (mean number of days...          Number
# 4  Percentage of older adults with a lifetime dia...               %
#
#   DataValueTypeID Data_Value_Type  Data_Value  ... High_Confidence_Limit  \
# 0           PRCTG      Percentage        26.3  ...                    29
# 1           PRCTG      Percentage        24.0  ...                    27
# 2           PRCTG      Percentage        35.7  ...                  39.1
# 3            MEAN            Mean         4.8  ...                   5.5
# 4           PRCTG      Percentage        13.7  ...                  15.4
#
#   StratificationCategory1 Stratification1 StratificationCategory2  \
# 0               Age Group     50-64 years                     NaN
# 1               Age Group     50-64 years                     NaN
# 2               Age Group     50-64 years                     NaN
# 3               Age Group     50-64 years                     NaN
# 4               Age Group         Overall                  Gender
#
#   Stratification2 QuestionID StratificationCategoryID1 StratificationID1  \
# 0             NaN        Q43                       AGE              5064
# 1             NaN        Q27                       AGE              5064
# 2             NaN        Q43                       AGE              5064
# 3             NaN        Q08                       AGE              5064
# 4            Male        Q27                       AGE       AGE_OVERALL
#
#   StratificationCategoryID2 StratificationID2
# 0                   OVERALL           OVERALL
# 1                   OVERALL           OVERALL
# 2                   OVERALL           OVERALL
# 3                   OVERALL           OVERALL
# 4                    GENDER              MALE
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Finally, it looks like there are plenty of rows that are missing from Data_Value
# The data from this set is aggregated from many different statistical studies across states. We cannot simply interpolate the data, so instead we will drop the missing rows.

# %%
df = df[df["Data_Value"].notnull()]

# %% [markdown]
# #### We took the dataset from 214000 rows to 144629 rows! That's a lot of saved storage!

# %%
#Let's check if after removing those rows certain columns became null again
empty_columns = [i for i in df.columns if colisnull(df[i])]
df = df.drop(empty_columns,axis=1)
df.head()
# Out:
#    YearStart  YearEnd LocationDesc           Class  \
# 0       2020     2020       Hawaii  Overall Health
# 1       2017     2017        Idaho   Mental Health
# 2       2017     2017        Idaho  Overall Health
# 3       2018     2018        Idaho  Overall Health
# 4       2020     2020      Indiana   Mental Health
#
#                                              Topic  \
# 0                     Arthritis among older adults
# 1                 Lifetime diagnosis of depression
# 2                     Arthritis among older adults
# 3  Physically unhealthy days (mean number of days)
# 4                 Lifetime diagnosis of depression
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults ever told they have...               %
# 1  Percentage of older adults with a lifetime dia...               %
# 2  Percentage of older adults ever told they have...               %
# 3  Physically unhealthy days (mean number of days...          Number
# 4  Percentage of older adults with a lifetime dia...               %
#
#   DataValueTypeID Data_Value_Type  Data_Value  ... High_Confidence_Limit  \
# 0           PRCTG      Percentage        26.3  ...                    29
# 1           PRCTG      Percentage        24.0  ...                    27
# 2           PRCTG      Percentage        35.7  ...                  39.1
# 3            MEAN            Mean         4.8  ...                   5.5
# 4           PRCTG      Percentage        13.7  ...                  15.4
#
#   StratificationCategory1 Stratification1 StratificationCategory2  \
# 0               Age Group     50-64 years                     NaN
# 1               Age Group     50-64 years                     NaN
# 2               Age Group     50-64 years                     NaN
# 3               Age Group     50-64 years                     NaN
# 4               Age Group         Overall                  Gender
#
#   Stratification2 QuestionID StratificationCategoryID1 StratificationID1  \
# 0             NaN        Q43                       AGE              5064
# 1             NaN        Q27                       AGE              5064
# 2             NaN        Q43                       AGE              5064
# 3             NaN        Q08                       AGE              5064
# 4            Male        Q27                       AGE       AGE_OVERALL
#
#   StratificationCategoryID2 StratificationID2
# 0                   OVERALL           OVERALL
# 1                   OVERALL           OVERALL
# 2                   OVERALL           OVERALL
# 3                   OVERALL           OVERALL
# 4                    GENDER              MALE
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Taking a look at the data

# %%
#Now after all of that cleaning we can finally get to work visualizing the data on hand
#First, let's check to see the different categories of data 
plt.rcParams["figure.figsize"] = (20,7)

color_list = [{c<12000: 'purple', 12000<=c<=40000: 'orange', c>40000: 'green'}[True] for c in df["Class"].value_counts()]
x = df["Class"].value_counts()
fig = plt.bar(x.index,df["Class"].value_counts(),color = color_list)
plt.title("Medical Category Breakdown")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Choose a Category and Question to Analyze
#
# I like the following question: "Percentage of older adults who reported subjective cognitive decline or memory loss that is happening more often or is getting worse in the preceding 12 months"
#
# This question is labeled 'Q30' in the QuestionID column.
#
# Let's see what type of analysis we can perform!

# %%
#Let's choose one of the questions to analyze
q1 = df[df["QuestionID"] == 'Q30'].sort_values('LocationDesc')
#To make our lives easier we are going to sort the data only to the long-running five year studies
q1 = q1[q1["YearStart"] == 2015]
q1 = q1[q1["YearEnd"] == 2020]
q1.head()
# Out:
#        YearStart  YearEnd LocationDesc              Class  \
# 6543        2015     2020      Alabama  Cognitive Decline
# 3680        2015     2020      Alabama  Cognitive Decline
# 10145       2015     2020      Alabama  Cognitive Decline
# 3885        2015     2020      Alabama  Cognitive Decline
# 4857        2015     2020      Alabama  Cognitive Decline
#
#                                                    Topic  \
# 6543   Subjective cognitive decline or memory loss am...
# 3680   Subjective cognitive decline or memory loss am...
# 10145  Subjective cognitive decline or memory loss am...
# 3885   Subjective cognitive decline or memory loss am...
# 4857   Subjective cognitive decline or memory loss am...
#
#                                                 Question Data_Value_Unit  \
# 6543   Percentage of older adults who reported subjec...               %
# 3680   Percentage of older adults who reported subjec...               %
# 10145  Percentage of older adults who reported subjec...               %
# 3885   Percentage of older adults who reported subjec...               %
# 4857   Percentage of older adults who reported subjec...               %
#
#       DataValueTypeID Data_Value_Type  Data_Value  ... High_Confidence_Limit  \
# 6543            PRCTG      Percentage        15.2  ...                  19.1
# 3680            PRCTG      Percentage        14.8  ...                  17.4
# 10145           PRCTG      Percentage        13.8  ...                  18.2
# 3885            PRCTG      Percentage        14.2  ...                  16.5
# 4857            PRCTG      Percentage        15.0  ...                  17.4
#
#       StratificationCategory1    Stratification1 StratificationCategory2  \
# 6543                Age Group        50-64 years                  Gender
# 3680                Age Group            Overall                  Gender
# 10145               Age Group        50-64 years          Race/Ethnicity
# 3885                Age Group  65 years or older          Race/Ethnicity
# 4857                Age Group        50-64 years                     NaN
#
#            Stratification2 QuestionID StratificationCategoryID1  \
# 6543                  Male        Q30                       AGE
# 3680                  Male        Q30                       AGE
# 10145  Black, non-Hispanic        Q30                       AGE
# 3885   White, non-Hispanic        Q30                       AGE
# 4857                   NaN        Q30                       AGE
#
#       StratificationID1 StratificationCategoryID2 StratificationID2
# 6543               5064                    GENDER              MALE
# 3680        AGE_OVERALL                    GENDER              MALE
# 10145              5064                      RACE               BLK
# 3885             65PLUS                      RACE               WHT
# 4857               5064                   OVERALL           OVERALL
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Type of Analysis
#
# So we've got many different studies from the same state, but values are stratified by Gender, Race, and Age.
# Let's see if there's a difference in Data_Value between different races. This looks like it could be a good candidate for a paired-sample t-test.

# %%
#Breaking the data into different race datasets

race = q1[q1["StratificationCategoryID2"] == "RACE"]

blk = q1[q1["StratificationID2"] == 'BLK']
wht = q1[q1["StratificationID2"] == 'WHT']
naa = q1[q1["StratificationID2"] == 'NAA']
his = q1[q1["StratificationID2"] == 'HIS']
asn = q1[q1["StratificationID2"] == 'ASN']

# %% [markdown]
# ### Filter Data for Direct Comparison

# %%
#Final goal is to make a scatter plot colored by race
blk_filtered = blk[blk["StratificationID1"] == 'AGE_OVERALL']
wht_filtered = wht[wht["StratificationID1"] == 'AGE_OVERALL']

# %% [markdown]
# ## Merge the Data
#
# Here we are merging the Black and White datasets. We note that there is an unequal distribution of survey data. More survey results are available for White Americans than Black Americans. Again, interpolation is not a direct option, so instead we will filter the dataset into one with only the states which have data points for Black and White Americans.

# %%
#Merge the datasets by State
merged = pd.merge(wht_filtered, blk_filtered, on='LocationDesc', how='outer')
merged = merged[merged['QuestionID_y'].notnull()]
#df = df[df["Data_Value"].notnull()]
#merged
white = merged["Data_Value_x"]
black = merged["Data_Value_y"]
merged.head()
# Out:
#    YearStart_x  YearEnd_x          LocationDesc            Class_x  \
# 0         2015       2020               Alabama  Cognitive Decline
# 3         2015       2020              Arkansas  Cognitive Decline
# 6         2015       2020           Connecticut  Cognitive Decline
# 7         2015       2020              Delaware  Cognitive Decline
# 8         2015       2020  District of Columbia  Cognitive Decline
#
#                                              Topic_x  \
# 0  Subjective cognitive decline or memory loss am...
# 3  Subjective cognitive decline or memory loss am...
# 6  Subjective cognitive decline or memory loss am...
# 7  Subjective cognitive decline or memory loss am...
# 8  Subjective cognitive decline or memory loss am...
#
#                                           Question_x Data_Value_Unit_x  \
# 0  Percentage of older adults who reported subjec...                 %
# 3  Percentage of older adults who reported subjec...                 %
# 6  Percentage of older adults who reported subjec...                 %
# 7  Percentage of older adults who reported subjec...                 %
# 8  Percentage of older adults who reported subjec...                 %
#
#   DataValueTypeID_x Data_Value_Type_x  Data_Value_x  ...  \
# 0             PRCTG        Percentage          14.6  ...
# 3             PRCTG        Percentage          11.8  ...
# 6             PRCTG        Percentage           7.2  ...
# 7             PRCTG        Percentage           8.5  ...
# 8             PRCTG        Percentage           6.6  ...
#
#   High_Confidence_Limit_y StratificationCategory1_y Stratification1_y  \
# 0                    17.5                 Age Group           Overall
# 3                    17.9                 Age Group           Overall
# 6                      15                 Age Group           Overall
# 7                    14.3                 Age Group           Overall
# 8                    13.1                 Age Group           Overall
#
#   StratificationCategory2_y    Stratification2_y QuestionID_y  \
# 0            Race/Ethnicity  Black, non-Hispanic          Q30
# 3            Race/Ethnicity  Black, non-Hispanic          Q30
# 6            Race/Ethnicity  Black, non-Hispanic          Q30
# 7            Race/Ethnicity  Black, non-Hispanic          Q30
# 8            Race/Ethnicity  Black, non-Hispanic          Q30
#
#   StratificationCategoryID1_y StratificationID1_y StratificationCategoryID2_y  \
# 0                         AGE         AGE_OVERALL                        RACE
# 3                         AGE         AGE_OVERALL                        RACE
# 6                         AGE         AGE_OVERALL                        RACE
# 7                         AGE         AGE_OVERALL                        RACE
# 8                         AGE         AGE_OVERALL                        RACE
#
#   StratificationID2_y
# 0                 BLK
# 3                 BLK
# 6                 BLK
# 7                 BLK
# 8                 BLK
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Plot an Initial Histogram to Compare the Data

# %%
plt.rcParams["figure.figsize"] = (10,5)
plt.hist(black,label = '% Of Black Americans',alpha = 0.5)
plt.hist(white,label = '% Of White Americans',alpha = 0.7)
plt.title("Histogram % of Americans Experiencing Symptoms of Alzheimers Across States")
plt.xlabel("Percentage")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# ## Let's Do A Paired Sample T-Test to determine if there is a statistically significant difference between the two samples
#
#
# We are comparing across 27 different states to see if one population tends to experience a greater amount of reported cognitive memory decline. We have a sample size less than 30, so we will be doing a t-test. Our data is paired across states, so we will particularly be performing a paired sample t-test, making usage of the scipy library. Furthermore, we are going to do a one sided t-test based on the histogram above, where we predice Black americans to have a higher mean percentage than white americans.
#
# H0: There is no difference in the population means in percentages of Alzheimer related symmptoms between White Americans and Black Americans across the 27 chosen states.
#
# Ha: The mean percantage of White Americans experiencing Alzheimer symptoms is less than the mean percentage of Black Americans across the 27 chosen states.

# %%
t_val = st.ttest_rel(white,black,alternative='less')
t_val
# Out:
# Ttest_relResult(statistic=-2.6437381940938, pvalue=0.006856286254937451)

# %% [markdown]
# ### Our p-value was 0.00686, which is highly significant.
# We can reject the null hypothesis and conclude that the mean percentage of White Americans experiencing Alzheimer symptoms is less than the mean percentage of Black Americans across the 27 chosen states.

# %% [markdown]
# Thank you for reading through this Jupyter Notebook! Data cleaning is quite painful, but allows us to perform some powerful statistical tests.
